# %%
import sys

# 1. Defina o caminho absoluto ou relativo da pasta onde está o seu código Python
sys.path.insert(1, '../src')

# %%
from utils import *
from preprocessing import *
from help import *

# %%
arquivo = '../data/raw/telecon.csv'
df = carregar_csv(caminho=arquivo)

verificar_dataframe(df=df)
# Out:
#    customerID  Genero  Idoso Casado Dependents  Tempo_como_Cliente  \
# 0  7590-VHVEG  Female      0    Yes         No                   1
# 1  5575-GNVDE    Male      0     No         No                  34
# 2  3668-QPYBK    Male      0     No         No                   2
# 3  7795-CFOCW    Male      0     No         No                  45
# 4  9237-HQITU     NaN      0     No         No                   2
#
#   PhoneService Servico_Internet Servico_Seguranca Suporte_Tecnico StreamingTV  \
# 0           No              DSL                No              No          No
# 1          Yes              DSL               Yes              No          No
# 2          Yes              DSL               Yes              No          No
# 3           No              DSL               Yes             Yes          No
# 4          Yes      Fiber optic                No              No          No
#
#     Tipo_Contrato              PaymentMethod  Pagamento_Mensal  Total_Pago  \
# ...

# %%
novo_df = df.copy()

# %%
mostrar_percentual_nulos(df=novo_df)
# Out:
# Serão mostrados apenas as porcetagens de colunas com dados faltantes:
# ________________________________________________________________________________
#
# Coluna: Genero | Dados faltantes: 0.48%
#
# Pouco impacto. Pode remover linhas ou preencher com média, mediana ou moda.
# ________________________________________________________________________________
#
# Coluna: PhoneService | Dados faltantes: 59.28%
#
# A coluna possui muitos dados faltantes.
# Considere remover a coluna.
# Caso a variável seja booleana, dependendo do contexto, os valores nulos podem representar False.
# ________________________________________________________________________________
#
# Coluna: Pagamento_Mensal | Dados faltantes: 13.00%
#
# Dependendo do contexto, pode ser melhor imputar ou considerar remover a coluna.
# ________________________________________________________________________________
#
# Coluna: Churn | Dados faltantes: 0.20%
#
# ...

# %%
info_tratar_nulos()
# Out:
#         Estratégias disponíveis:
#
#         - remover_linhas
#         - remover_coluna
#         - media
#         - mediana
#         - moda
#
#         Exemplo:
#
#         tratar_nulos(df=nome_do_dataframe, coluna='nome_da_coluna', estrategia='media')

# %%
tratar_nulos(df=novo_df, coluna='Genero', estrategia='remover_linhas')

# %%
mostrar_percentual_nulos(df=novo_df)
# Out:
# Serão mostrados apenas as porcetagens de colunas com dados faltantes:
# ________________________________________________________________________________
#
# Coluna: PhoneService | Dados faltantes: 59.57%
#
# A coluna possui muitos dados faltantes.
# Considere remover a coluna.
# Caso a variável seja booleana, dependendo do contexto, os valores nulos podem representar False.
# ________________________________________________________________________________
#
# Coluna: Pagamento_Mensal | Dados faltantes: 12.58%
#
# Dependendo do contexto, pode ser melhor imputar ou considerar remover a coluna.
# ________________________________________________________________________________

# %%
# tratar_nulos(df=novo_df, coluna='PhoneService', estrategia='remover_coluna')

novo_df['PhoneService'] = novo_df['PhoneService'].fillna('No')

# %%
mostrar_percentual_nulos(df=novo_df)
# Out:
# Serão mostrados apenas as porcetagens de colunas com dados faltantes:
# ________________________________________________________________________________
#
# Coluna: Pagamento_Mensal | Dados faltantes: 12.58%
#
# Dependendo do contexto, pode ser melhor imputar ou considerar remover a coluna.
# ________________________________________________________________________________

# %%
novo_df.dtypes
# Out:
# customerID                str
# Genero                    str
# Idoso                   int64
# Casado                    str
# Dependents                str
# Tempo_como_Cliente      int64
# PhoneService              str
# Servico_Internet          str
# Servico_Seguranca         str
# Suporte_Tecnico           str
# StreamingTV               str
# Tipo_Contrato             str
# PaymentMethod             str
# Pagamento_Mensal      float64
# Total_Pago            float64
# Churn                     str
# dtype: object

# %%
info_converter_dados()
# Out:
#         Estratégias disponíveis para conversão de dados:
#
#         - int64
#             Converte valores inteiros.
#             Exemplo: 1, 2, 3
#
#         - float64
#             Converte valores decimais.
#             Exemplo: 10.5, 7.8
#
#         - string
#             Converte valores para texto.
#
#         - bool
#             Converte valores booleanos.
#             Exemplo: True ou False
#
#         - datetime
#             Converte valores para data.
#             Exemplo: 2025-01-01
#
#         - category
#             Converte valores categóricos para otimizar memória.
#             Muito útil para colunas com poucos valores únicos.
#
#         Exemplo de uso:
#
#         novo_df = converter_dados(df=nome_do_dataframe, coluna='nome_da_coluna', estrategia='datetime')

# %%
novo_df['Tempo_como_Cliente'] = (novo_df['Tempo_como_Cliente'].replace(0, 1))

novo_df['Pagamento_Mensal'] = novo_df['Total_Pago'] / novo_df['Tempo_como_Cliente']

# %%
novo_df = mapear_coluna(df=novo_df,coluna='Churn',mapeamento={'Yes': 1,'No': 0})

# %%
novo_df.head()
# Out:
#     customerID  Genero  Idoso Casado Dependents  Tempo_como_Cliente  \
# 0   7590-VHVEG  Female      0    Yes         No                   1
# 1   5575-GNVDE    Male      0     No         No                  34
# 2   3668-QPYBK    Male      0     No         No                   2
# 3   7795-CFOCW    Male      0     No         No                  45
# 16  8191-XWSZG       F      0     No         No                  52
#
#    PhoneService Servico_Internet    Servico_Seguranca      Suporte_Tecnico  \
# 0            No              DSL                   No                   No
# 1           Yes              DSL                  Yes                   No
# 2           Yes              DSL                  Yes                   No
# 3            No              DSL                  Yes                  Yes
# 16          Yes               No  No internet service  No internet service
#
#             StreamingTV   Tipo_Contrato              PaymentMethod  \
# ...

# %%
mostrar_percentual_nulos(df=novo_df)
# Out:
# Serão mostrados apenas as porcetagens de colunas com dados faltantes:
# ________________________________________________________________________________
# Não existe nenhuma coluna com dados faltantes.
